# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load an image of a bird
original_img = plt.imread('img1.jpeg')

# %%
# Visualizing the image
plt.imshow(original_img)

# %%
original_img.shape
# Out:
# (1599, 899, 3)

# %%
# Data Normalization
# Divide by 255 so that all values are in the range 0 - 1
original_img = original_img / 255

# %%
X_img = np.reshape(original_img, (original_img.shape[0] * original_img.shape[1], 3))

# %%
X_img.shape
# Out:
# (1437501, 3)

# %%
kmeans = KMeans(n_clusters=16, max_iter=10, random_state=16, n_init=10).fit(X_img)

# %%
kmeans.cluster_centers_
# Out:
# array([[0.26864221, 0.30730273, 0.4152353 ],
#        [0.79382204, 0.57946658, 0.4895938 ],
#        [0.00228464, 0.0010854 , 0.00229071],
#        [0.5920055 , 0.1604645 , 0.18302247],
#        [0.39189268, 0.42112137, 0.51456053],
#        [0.9612208 , 0.88421539, 0.82431317],
#        [0.94282002, 0.72773521, 0.62865833],
#        [0.13654546, 0.10847943, 0.14064764],
#        [0.6735698 , 0.66449932, 0.67962145],
#        [0.46611107, 0.44864724, 0.4524128 ],
#        [0.55751279, 0.54285836, 0.55300212],
#        [0.18845634, 0.23138851, 0.34110048],
#        [0.38497726, 0.35351862, 0.35383587],
#        [0.33488512, 0.37109453, 0.46843741],
#        [0.33625789, 0.23056984, 0.21432697],
#        [0.60208938, 0.39849104, 0.33495183]])

# %%
kmeans.labels_
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
kmeans.labels_.shape
# Out:
# (1437501,)

# %%
kmeans.labels_[:5]
# Out:
# array([2, 2, 2, 2, 2])

# %%
# Represent image in terms of indices
X_recovered = kmeans.cluster_centers_[kmeans.labels_, :]

# %%
X_recovered
# Out:
# array([[0.00228464, 0.0010854 , 0.00229071],
#        [0.00228464, 0.0010854 , 0.00229071],
#        [0.00228464, 0.0010854 , 0.00229071],
#        ...,
#        [0.00228464, 0.0010854 , 0.00229071],
#        [0.00228464, 0.0010854 , 0.00229071],
#        [0.00228464, 0.0010854 , 0.00229071]])

# %%
# Reshape recovered image into proper dimensions
X_recovered = np.reshape(X_recovered, original_img.shape)

# %%
plt.imshow(original_img)

# %%
plt.imshow(X_recovered)
